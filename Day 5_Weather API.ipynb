# %%
import requests
api_key = '5247e872b7fa41388d053724242802'
city = 'Eluru'
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'location': {'name': 'Eluru', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.7, 'lon': 81.1, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709101339, 'localtime': '2024-02-28 11:52'}, 'current': {'last_updated_epoch': 1709100900, 'last_updated': '2024-02-28 11:45', 'temp_c': 31.0, 'temp_f': 87.8, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 6.9, 'wind_kph': 11.2, 'wind_degree': 90, 'wind_dir': 'E', 'pressure_mb': 1014.0, 'pressure_in': 29.94, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 52, 'cloud': 25, 'feelslike_c': 30.4, 'feelslike_f': 86.7, 'vis_km': 6.0, 'vis_miles': 3.0, 'uv': 8.0, 'gust_mph': 7.5, 'gust_kph': 12.0}}

# %%
type(data)
# Out:
# dict

# %%
print("City:",data['location']['name'])
print("State:",data['location']['region'])
print("Country:",data['location']['country'])
print("Tempreture:",data['current']['temp_c'])
print("Wind speed:",data['current']['wind_mph'])
print("feels:",data['current']['feelslike_c'])
print("Humidity:",data['current']['humidity'])
print("Wind direction:",data['current']['wind_dir'])
print("Cloud:",data['current']['cloud'])
# Out:
# City: Eluru
# State: Andhra Pradesh
# Country: India
# Tempreture: 31.0
# Wind speed: 6.9
# feels: 30.4
# Humidity: 52
# Wind direction: E
# Cloud: 25

# %%
city= input("Enter city name")
data = response.json()
print("City:",data['location']['name'])
print("State:",data['location']['region'])
print("Country:",data['location']['country'])
print("Tempreture:",data['current']['temp_c'])
print("Wind speed:",data['current']['wind_mph'])
print("feels:",data['current']['feelslike_c'])
print("Humidity:",data['current']['humidity'])
print("Wind direction:",data['current']['wind_dir'])
print("Cloud:",data['current']['cloud'])
# Out:
# Enter city nameVijayawada
# City: Eluru
# State: Andhra Pradesh
# Country: India
# Tempreture: 31.0
# Wind speed: 6.9
# feels: 30.4
# Humidity: 52
# Wind direction: E
# Cloud: 25

# %%
city= input("Enter city name")
api_key = '5247e872b7fa41388d053724242802'
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(url)
data = response.json()
print("City:",data['location']['name'])
print("State:",data['location']['region'])
print("Country:",data['location']['country'])
print("Tempreture:",data['current']['temp_c'])
print("Wind speed:",data['current']['wind_mph'])
print("feels:",data['current']['feelslike_c'])
print("Humidity:",data['current']['humidity'])
print("Wind direction:",data['current']['wind_dir'])
print("Cloud:",data['current']['cloud'])
# Out:
# Enter city nameVijayawada
# City: Vijayawada
# State: Andhra Pradesh
# Country: India
# Tempreture: 31.0
# Wind speed: 6.9
# feels: 30.1
# Humidity: 52
# Wind direction: E
# Cloud: 25

# %%
city= input("Enter city name:")
api_key = '5247e872b7fa41388d053724242802'
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(url)
data = response.json()
if response.status_code == 200:
  print("City:",data['location']['name'])
  print("State:",data['location']['region'])
  print("Country:",data['location']['country'])
  print("Tempreture:",data['current']['temp_c'])
  print("Wind speed:",data['current']['wind_mph'])
  print("feels:",data['current']['feelslike_c'])
  print("Humidity:",data['current']['humidity'])
  print("Wind direction:",data['current']['wind_dir'])
  print("Cloud:",data['current']['cloud'])
else:
  print(data['error']['code'])
# Out:
# Enter city name:skjavj i
# City: K I Sawyer A F B
# State: Michigan
# Country: USA United States of America
# Tempreture: -4.4
# Wind speed: 27.3
# feels: -11.9
# Humidity: 88
# Wind direction: NNW
# Cloud: 0
